# %%
import cv2
import numpy as np
import pickle
import random
import copy
import pandas as pd
import os

# %% [markdown]
# # Generate Datasets

# %%
def read_image(img_path, show=False):
    """
    # Function
    Read image into numpy array
    # Parameter
    img_path: string
        full path of an image
    """
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)# return a object
    if not img.dtype == np.uint8:
        pass

    if show:
        show_image(img)
    
    return img

# %%
def img2data_img(path, dic):
    """
    # Function
    Create a dictionary whose keys are all image names, values are image matrix
    # Parameters
    path: string
        path of the directory that contains images
    dic: dictionary
        input dictionrary to which will be added image matrix
    """
    for file in os.listdir(path):
        fullpath=path+file
        file_split=file.split(".")
        ext=file_split[1]
        img_name=file_split[0]
        if ext=="png":
            img=read_image(fullpath)
            if img_name in dic:
                print("same file name")
            else:
                dic[img_name]=[img]
    return dic

# %%
def pair_img(df, dic, shuffle=False):
    """
    # Function
    Create pairs of data that can fit into Siamese network
    # Parameters
    df: DataFrame
        the seen, unseen or shuffle dataset
    dic: dictionray
        the dictionary that contains all the image matrix
    """
    if shuffle:
        df=df.sample(frac=1)
    arr=np.array(df[["left","right","label"]])
    pair=[]
    label=[]
    for i in range(arr.shape[0]):
        row=arr[i,:]
        left_name=row[0].split('.')[0]
        right_name=row[1].split('.')[0]
        if (left_name not in dic) or (right_name not in dic):
            continue
        left=np.expand_dims(dic[left_name][0],axis=2) # left img 
        right=np.expand_dims(dic[right_name][0],axis=2) # right img 
        pair.append([left,right])# concatenate the left and right image matrix
        label.append(row[2])
    return np.array(pair,dtype="double"),np.array(label,dtype="double")

# %%
cwd = os.getcwd()
data_dic={}
impath=cwd+"/seen-dataset/TrainingSet/" # include images in seen dataset
data_dic=img2data_img(impath,data_dic)
impath=cwd+"/seen-dataset/ValidationSet/"
data_dic=img2data_img(impath,data_dic)
impath=cwd+"/unseen-dataset/TrainingSet/"# include images in unseen dataset
data_dic=img2data_img(impath,data_dic)
impath=cwd+"/unseen-dataset/ValidationSet/"
data_dic=img2data_img(impath,data_dic)
# Out:
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# ...
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name
# same file name

# %%
"""
Create training and validation dataset from the dictionary
"""
# training data in seen
df_seen_tr=pd.read_csv(cwd+"/seen-dataset/dataset_seen_training_siamese.csv")
pairs_seen_tr, y_seen_tr=pair_img(df_seen_tr, data_dic, shuffle=True)
# validation data in seen
df_seen_va=pd.read_csv(cwd+"/seen-dataset/dataset_seen_validation_siamese.csv")
pairs_seen_va, y_seen_va=pair_img(df_seen_va, data_dic, shuffle=True)
# training data in unseen
df_unseen_tr=pd.read_csv(cwd+"/unseen-dataset/dataset_seen_training_siamese.csv")
pairs_unseen_tr, y_unseen_tr=pair_img(df_unseen_tr, data_dic, shuffle=True)
# validation data in unseen
df_unseen_va=pd.read_csv(cwd+"/unseen-dataset/dataset_seen_validation_siamese.csv")
pairs_unseen_va, y_unseen_va=pair_img(df_unseen_va, data_dic, shuffle=True)
# traning data in shuffled
df_shuffle_tr=pd.read_csv(cwd+"/shuffled-dataset/dataset_seen_training_siamese.csv")
pairs_shuffle_tr, y_shuffle_tr=pair_img(df_shuffle_tr, data_dic)
# validation data in shuffled
df_shuffle_va=pd.read_csv(cwd+"/shuffled-dataset/dataset_seen_validation_siamese.csv")
pairs_shuffle_va, y_shuffle_va=pair_img(df_shuffle_va, data_dic)

# %%
"""
The dataset for Siamest network training
"""
# data_dic_writer=img2data(impath)
# tr_dic,va_dic,te_dic=split_data(data_dic_writer,0.8,0.1,0.1)
# tr_pairs, tr_y=sample_pairs(tr_dic)
# va_pairs, va_y=sample_pairs(va_dic)
# print(np.sum(dic_size(tr_dic)),np.sum(dic_size(va_dic)),np.sum(dic_size(te_dic)))

tr_pairs, tr_y=pairs_seen_tr, y_seen_tr
va_pairs, va_y=pairs_seen_va, y_seen_va
print(tr_pairs.shape,va_pairs.shape)
# Out:
# (114390, 2, 64, 64, 1) (906, 2, 64, 64, 1)

# %% [markdown]
# # Build Deep Learning Model

# %%
from keras.models import Model
from keras.optimizers import Adadelta, SGD, Adam, RMSprop
from keras.layers import Input,Conv2D,MaxPooling2D,BatchNormalization,Activation,Reshape,UpSampling2D,Flatten,Lambda
from keras import backend as K
from keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
def create_basenet(imDim):
    input_shape  = (imDim,imDim,1)
    inp_img = Input(shape = (imDim,imDim,1))
    model = inp_img
    model = Conv2D(16,kernel_size=(3, 3),activation='relu',padding='valid')(model)
    model = MaxPooling2D((2,2), padding='valid')(model)
    # second
    model = Conv2D(32, (3, 3), activation='relu',padding='valid')(model)
    model = MaxPooling2D((2,2),padding='valid')(model)
    # third
    model = Conv2D(32, (3, 3), activation='relu',padding='valid')(model)
    model = MaxPooling2D((2,2),padding='valid')(model)
    
    model = Flatten()(model)
    base=Model(inputs=[inp_img], outputs=[model],name = 'base_model')
    return base
def cal_distance(inputs):
    """
    # Parameter
    inputs: list of tensor of left and right process
    """
    x1,x2=inputs
    sumofsquare=K.sum(K.square(x1-x2),axis=1,keepdims=True)
    return K.sqrt(K.maximum(sumofsquare, K.epsilon())) # final output is the eu-distance btw two imgs
def distance_shape(shape):
    s1, s2=shape
    return (s1[0],1)# same shape of s1 and s2
def contrastive_loss(y_true,dist): # input argument (true output, predict output)
    """
    # Parameter
    y_true: numpy array
        true label of verification
    dist: tensor
        eu-distance between two imgages
    """
    margin=0.05
    same=K.square(dist) # 
    diff=K.square(K.maximum(margin-dist,0))
    return y_true*same+(1-y_true)*diff
def accuracy(y_true,dist):
    """
    Create a tensor that is used as accuracy in model training
    """
    th=0.2
    return K.mean(K.equal(y_true, K.cast(dist < th, y_true.dtype)))
def acc_scalar(y_true, dist):
    """
    A scalar accuracy and return a scalar
    """
    th=0.2
    y_pred=(dist<th)*1.0
    y_pred=y_pred.reshape(-1)
    right=np.where(y_pred==y_true)[0].shape[0]
#     print(y_pred.shape, y_true.shape)
#     print(y_true.shape[0],right)
    return right/y_true.shape[0]

# %%
"""
Create base network which is shared by left and right image
"""
imDim=64
base_network=create_basenet(imDim)
base_network.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 64, 64, 1)         0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 62, 62, 16)        160
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 31, 31, 16)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 29, 29, 32)        4640
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 12, 12, 32)        9248
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 6, 6, 32)          0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 1152)              0
# =================================================================
# Total params: 14,048
# Trainable params: 14,048
# Non-trainable params: 0
# _________________________________________________________________

# %%
"""
Create Siamese network, using euclidean distance between two images as output
"""
input_left=Input(shape = (imDim,imDim,1), name = 'left_image') # input layer for left image
input_right=Input(shape = (imDim,imDim,1), name = 'right_image') # input layer for right image
ts_left=base_network(input_left)
ts_right=base_network(input_right)
print(ts_left.shape)
distance=Lambda(cal_distance,output_shape=distance_shape)([ts_left,ts_right])# create a tensor that calcualte the distance
print(distance.shape)
distance=BatchNormalization()(distance)# normalize the distance
model=Model([input_left,input_right],distance)
model.summary()
# Out:
# (?, ?)
# (?, 1)
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# left_image (InputLayer)         (None, 64, 64, 1)    0
# __________________________________________________________________________________________________
# right_image (InputLayer)        (None, 64, 64, 1)    0
# __________________________________________________________________________________________________
# base_model (Model)              (None, 1152)         14048       left_image[0][0]
#                                                                  right_image[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 1)            0           base_model[1][0]
#                                                                  base_model[2][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 1)            4           lambda_4[0][0]
# ==================================================================================================
# Total params: 14,052
# Trainable params: 14,050
# Non-trainable params: 2
# __________________________________________________________________________________________________

# %%
tr_pairs.shape, tr_y.shape
# Out:
# ((114390, 2, 64, 64, 1), (114390,))

# %%
def datagen(batch_size, tr_pairs, tr_y):
    count=0
    num_all=tr_pairs.shape[0]
    arr=np.arange(0,num_all)
    np.random.shuffle(arr)
    start=0
    index_list=[]
    while True:
        if start>=num_all:
            start=0
            np.random.shuffle(arr)
            continue
        end=start+batch_size
        if end>num_all:
            index_list=np.copy(arr[start:])
            start=0
            np.random.shuffle(arr)
        else:
            index_list=np.copy(arr[start:end])
            start=start+batch_size
        yield [tr_pairs[index_list,0],tr_pairs[index_list,1]], tr_y[index_list]

# %%
tg=datagen(64, tr_pairs, tr_y)
vg=datagen(64, va_pairs, va_y)

# %%
mc = ModelCheckpoint(filepath='task3_siamese_seen.h5', monitor='val_loss',period=1,
                     save_best_only=True,save_weights_only=True,mode='auto',verbose=3)
es = EarlyStopping(patience=100, monitor='val_loss', min_delta=0.005, mode='auto')

# %%
"""
Train model
"""
# early_patience=20
# earlystopping_cb = EarlyStopping(monitor='val_loss', verbose=1, patience=early_patience, mode='min')
EPOCHS=2000
INIT_LR=1e-4
opt = Adadelta(lr=INIT_LR, decay=1e-04)
model.compile(loss=contrastive_loss,optimizer=opt,metrics=[accuracy])
# hist=model.fit([tr_pairs[:,0],tr_pairs[:,1]],tr_y,
#                   batch_size=64,epochs=1,
# #                   validation_data=([va_pairs[:,0],va_pairs[:,1]],va_y),
# #                   shuffle=True
#                   validation_split=0.2
#                   )
hist = model.fit_generator(tg, callbacks=[mc,es]
                                    , epochs=EPOCHS
                                    , steps_per_epoch = 1
                                    , validation_data = vg
                                    , validation_steps = 1
                                    , verbose = 3
                                    
                                   )
# Out:
# Epoch 1/2000
#
# Epoch 00001: val_loss improved from inf to 0.37361, saving model to task3_siamese_seen.h5
# Epoch 2/2000
#
# Epoch 00002: val_loss did not improve from 0.37361
# Epoch 3/2000
#
# Epoch 00003: val_loss improved from 0.37361 to 0.30830, saving model to task3_siamese_seen.h5
# Epoch 4/2000
#
# Epoch 00004: val_loss did not improve from 0.30830
# Epoch 5/2000
#
# Epoch 00005: val_loss did not improve from 0.30830
# Epoch 6/2000
#
# Epoch 00006: val_loss did not improve from 0.30830
# Epoch 7/2000
#
# Epoch 00007: val_loss did not improve from 0.30830
# Epoch 8/2000
#
# Epoch 00008: val_loss did not improve from 0.30830
# Epoch 9/2000
#
# Epoch 00009: val_loss did not improve from 0.30830
# Epoch 10/2000
#
# Epoch 00010: val_loss did not improve from 0.30830
# Epoch 11/2000
#
# Epoch 00011: val_loss did not improve from 0.30830
# Epoch 12/2000
#
# Epoch 00012: val_loss did not improve from 0.30830
# Epoch 13/2000
#
# Epoch 00013: val_loss did not improve from 0.30830
# Epoch 14/2000
#
# Epoch 00014: val_loss did not improve from 0.30830
# Epoch 15/2000
#
# Epoch 00015: val_loss did not improve from 0.30830
# Epoch 16/2000
#
# Epoch 00016: val_loss did not improve from 0.30830
# Epoch 17/2000
#
# Epoch 00017: val_loss did not improve from 0.30830
# Epoch 18/2000
#
# Epoch 00018: val_loss did not improve from 0.30830
# Epoch 19/2000
#
# Epoch 00019: val_loss did not improve from 0.30830
# Epoch 20/2000
#
# Epoch 00020: val_loss did not improve from 0.30830
# Epoch 21/2000
#
# Epoch 00021: val_loss did not improve from 0.30830
# Epoch 22/2000
#
# Epoch 00022: val_loss improved from 0.30830 to 0.26219, saving model to task3_siamese_seen.h5
# Epoch 23/2000
#
# Epoch 00023: val_loss did not improve from 0.26219
# Epoch 24/2000
#
# Epoch 00024: val_loss did not improve from 0.26219
# Epoch 25/2000
#
# Epoch 00025: val_loss did not improve from 0.26219
# Epoch 26/2000
#
# Epoch 00026: val_loss did not improve from 0.26219
# Epoch 27/2000
#
# Epoch 00027: val_loss did not improve from 0.26219
# Epoch 28/2000
#
# Epoch 00028: val_loss did not improve from 0.26219
# Epoch 29/2000
#
# Epoch 00029: val_loss did not improve from 0.26219
# Epoch 30/2000
#
# Epoch 00030: val_loss did not improve from 0.26219
# Epoch 31/2000
#
# Epoch 00031: val_loss did not improve from 0.26219
# Epoch 32/2000
#
# Epoch 00032: val_loss did not improve from 0.26219
# Epoch 33/2000
#
# Epoch 00033: val_loss did not improve from 0.26219
# Epoch 34/2000
#
# Epoch 00034: val_loss did not improve from 0.26219
# Epoch 35/2000
#
# Epoch 00035: val_loss did not improve from 0.26219
# Epoch 36/2000
#
# Epoch 00036: val_loss did not improve from 0.26219
# Epoch 37/2000
#
# Epoch 00037: val_loss did not improve from 0.26219
# Epoch 38/2000
#
# Epoch 00038: val_loss did not improve from 0.26219
# Epoch 39/2000
#
# Epoch 00039: val_loss did not improve from 0.26219
# Epoch 40/2000
#
# Epoch 00040: val_loss did not improve from 0.26219
# Epoch 41/2000
#
# Epoch 00041: val_loss did not improve from 0.26219
# Epoch 42/2000
#
# Epoch 00042: val_loss did not improve from 0.26219
# Epoch 43/2000
#
# Epoch 00043: val_loss did not improve from 0.26219
# Epoch 44/2000
#
# Epoch 00044: val_loss did not improve from 0.26219
# Epoch 45/2000
#
# Epoch 00045: val_loss did not improve from 0.26219
# Epoch 46/2000
#
# Epoch 00046: val_loss did not improve from 0.26219
# Epoch 47/2000
#
# Epoch 00047: val_loss did not improve from 0.26219
# Epoch 48/2000
#
# Epoch 00048: val_loss did not improve from 0.26219
# Epoch 49/2000
#
# Epoch 00049: val_loss did not improve from 0.26219
# Epoch 50/2000
#
# Epoch 00050: val_loss did not improve from 0.26219
# Epoch 51/2000
#
# Epoch 00051: val_loss did not improve from 0.26219
# Epoch 52/2000
#
# Epoch 00052: val_loss did not improve from 0.26219
# Epoch 53/2000
#
# Epoch 00053: val_loss did not improve from 0.26219
# Epoch 54/2000
#
# Epoch 00054: val_loss did not improve from 0.26219
# Epoch 55/2000
#
# Epoch 00055: val_loss did not improve from 0.26219
# Epoch 56/2000
#
# Epoch 00056: val_loss did not improve from 0.26219
# Epoch 57/2000
#
# Epoch 00057: val_loss did not improve from 0.26219
# Epoch 58/2000
#
# Epoch 00058: val_loss did not improve from 0.26219
# Epoch 59/2000
#
# Epoch 00059: val_loss did not improve from 0.26219
# Epoch 60/2000
#
# Epoch 00060: val_loss improved from 0.26219 to 0.13801, saving model to task3_siamese_seen.h5
# Epoch 61/2000
#
# Epoch 00061: val_loss did not improve from 0.13801
# Epoch 62/2000
#
# Epoch 00062: val_loss did not improve from 0.13801
# Epoch 63/2000
#
# Epoch 00063: val_loss did not improve from 0.13801
# Epoch 64/2000
#
# Epoch 00064: val_loss did not improve from 0.13801
# Epoch 65/2000
#
# Epoch 00065: val_loss did not improve from 0.13801
# Epoch 66/2000
#
# Epoch 00066: val_loss did not improve from 0.13801
# Epoch 67/2000
#
# Epoch 00067: val_loss did not improve from 0.13801
# Epoch 68/2000
#
# Epoch 00068: val_loss did not improve from 0.13801
# Epoch 69/2000
#
# Epoch 00069: val_loss did not improve from 0.13801
# Epoch 70/2000
#
# Epoch 00070: val_loss did not improve from 0.13801
# Epoch 71/2000
#
# Epoch 00071: val_loss did not improve from 0.13801
# Epoch 72/2000
#
# Epoch 00072: val_loss did not improve from 0.13801
# Epoch 73/2000
#
# Epoch 00073: val_loss did not improve from 0.13801
# Epoch 74/2000
#
# Epoch 00074: val_loss did not improve from 0.13801
# Epoch 75/2000
#
# Epoch 00075: val_loss did not improve from 0.13801
# Epoch 76/2000
#
# Epoch 00076: val_loss did not improve from 0.13801
# Epoch 77/2000
#
# Epoch 00077: val_loss did not improve from 0.13801
# Epoch 78/2000
#
# Epoch 00078: val_loss did not improve from 0.13801
# Epoch 79/2000
#
# Epoch 00079: val_loss did not improve from 0.13801
# Epoch 80/2000
#
# Epoch 00080: val_loss did not improve from 0.13801
# Epoch 81/2000
#
# Epoch 00081: val_loss did not improve from 0.13801
# Epoch 82/2000
#
# Epoch 00082: val_loss did not improve from 0.13801
# Epoch 83/2000
#
# Epoch 00083: val_loss did not improve from 0.13801
# Epoch 84/2000
#
# Epoch 00084: val_loss did not improve from 0.13801
# Epoch 85/2000
#
# Epoch 00085: val_loss did not improve from 0.13801
# Epoch 86/2000
#
# Epoch 00086: val_loss did not improve from 0.13801
# Epoch 87/2000
#
# Epoch 00087: val_loss did not improve from 0.13801
# Epoch 88/2000
#
# Epoch 00088: val_loss did not improve from 0.13801
# Epoch 89/2000
#
# Epoch 00089: val_loss did not improve from 0.13801
# Epoch 90/2000
#
# Epoch 00090: val_loss did not improve from 0.13801
# Epoch 91/2000
#
# Epoch 00091: val_loss did not improve from 0.13801
# Epoch 92/2000
#
# Epoch 00092: val_loss did not improve from 0.13801
# Epoch 93/2000
#
# Epoch 00093: val_loss did not improve from 0.13801
# Epoch 94/2000
#
# Epoch 00094: val_loss did not improve from 0.13801
# Epoch 95/2000
#
# Epoch 00095: val_loss did not improve from 0.13801
# Epoch 96/2000
#
# Epoch 00096: val_loss did not improve from 0.13801
# Epoch 97/2000
#
# Epoch 00097: val_loss did not improve from 0.13801
# Epoch 98/2000
#
# Epoch 00098: val_loss did not improve from 0.13801
# Epoch 99/2000
#
# Epoch 00099: val_loss did not improve from 0.13801
# Epoch 100/2000
#
# Epoch 00100: val_loss did not improve from 0.13801
# Epoch 101/2000
#
# Epoch 00101: val_loss did not improve from 0.13801
# Epoch 102/2000
#
# Epoch 00102: val_loss did not improve from 0.13801
# Epoch 103/2000
#
# Epoch 00103: val_loss did not improve from 0.13801
# Epoch 104/2000
#
# Epoch 00104: val_loss did not improve from 0.13801
# Epoch 105/2000
#
# Epoch 00105: val_loss did not improve from 0.13801
# Epoch 106/2000
#
# Epoch 00106: val_loss did not improve from 0.13801
# Epoch 107/2000
#
# Epoch 00107: val_loss did not improve from 0.13801
# Epoch 108/2000
#
# Epoch 00108: val_loss did not improve from 0.13801
# Epoch 109/2000
#
# Epoch 00109: val_loss did not improve from 0.13801
# Epoch 110/2000
#
# Epoch 00110: val_loss did not improve from 0.13801
# Epoch 111/2000
#
# Epoch 00111: val_loss did not improve from 0.13801
# Epoch 112/2000
#
# Epoch 00112: val_loss did not improve from 0.13801
# Epoch 113/2000
#
# Epoch 00113: val_loss did not improve from 0.13801
# Epoch 114/2000
#
# Epoch 00114: val_loss did not improve from 0.13801
# Epoch 115/2000
#
# Epoch 00115: val_loss did not improve from 0.13801
# Epoch 116/2000
#
# Epoch 00116: val_loss did not improve from 0.13801
# Epoch 117/2000
#
# Epoch 00117: val_loss did not improve from 0.13801
# Epoch 118/2000
#
# Epoch 00118: val_loss did not improve from 0.13801
# Epoch 119/2000
#
# Epoch 00119: val_loss did not improve from 0.13801
# Epoch 120/2000
#
# Epoch 00120: val_loss did not improve from 0.13801
# Epoch 121/2000
#
# Epoch 00121: val_loss did not improve from 0.13801
# Epoch 122/2000
#
# Epoch 00122: val_loss did not improve from 0.13801
# Epoch 123/2000
# Epoch 00123: val_loss did not improve from 0.13801
# Epoch 124/2000
#
# Epoch 00124: val_loss did not improve from 0.13801
# Epoch 125/2000
#
# Epoch 00125: val_loss did not improve from 0.13801
# Epoch 126/2000
#
# Epoch 00126: val_loss did not improve from 0.13801
# Epoch 127/2000
#
# Epoch 00127: val_loss did not improve from 0.13801
# Epoch 128/2000
#
# Epoch 00128: val_loss did not improve from 0.13801
# Epoch 129/2000
#
# Epoch 00129: val_loss did not improve from 0.13801
# Epoch 130/2000
#
# Epoch 00130: val_loss did not improve from 0.13801
# Epoch 131/2000
#
# Epoch 00131: val_loss did not improve from 0.13801
# Epoch 132/2000
#
# Epoch 00132: val_loss did not improve from 0.13801
# Epoch 133/2000
#
# Epoch 00133: val_loss did not improve from 0.13801
# Epoch 134/2000
#
# Epoch 00134: val_loss did not improve from 0.13801
# Epoch 135/2000
#
# Epoch 00135: val_loss did not improve from 0.13801
# Epoch 136/2000
#
# Epoch 00136: val_loss did not improve from 0.13801
# Epoch 137/2000
#
# Epoch 00137: val_loss did not improve from 0.13801
# Epoch 138/2000
#
# Epoch 00138: val_loss did not improve from 0.13801
# Epoch 139/2000
#
# Epoch 00139: val_loss did not improve from 0.13801
# Epoch 140/2000
#
# Epoch 00140: val_loss did not improve from 0.13801
# Epoch 141/2000
#
# Epoch 00141: val_loss did not improve from 0.13801
# Epoch 142/2000
#
# Epoch 00142: val_loss did not improve from 0.13801
# Epoch 143/2000
#
# Epoch 00143: val_loss did not improve from 0.13801
# Epoch 144/2000
#
# Epoch 00144: val_loss did not improve from 0.13801
# Epoch 145/2000
#
# Epoch 00145: val_loss did not improve from 0.13801
# Epoch 146/2000
#
# Epoch 00146: val_loss did not improve from 0.13801
# Epoch 147/2000
#
# Epoch 00147: val_loss did not improve from 0.13801
# Epoch 148/2000
#
# Epoch 00148: val_loss did not improve from 0.13801
# Epoch 149/2000
#
# Epoch 00149: val_loss did not improve from 0.13801
# Epoch 150/2000
#
# Epoch 00150: val_loss did not improve from 0.13801
# Epoch 151/2000
#
# Epoch 00151: val_loss did not improve from 0.13801
# Epoch 152/2000
#
# Epoch 00152: val_loss did not improve from 0.13801
# Epoch 153/2000
#
# Epoch 00153: val_loss did not improve from 0.13801
# Epoch 154/2000
#
# Epoch 00154: val_loss did not improve from 0.13801
# Epoch 155/2000
#
# Epoch 00155: val_loss did not improve from 0.13801
# Epoch 156/2000
#
# Epoch 00156: val_loss did not improve from 0.13801
# Epoch 157/2000
#
# Epoch 00157: val_loss did not improve from 0.13801
# Epoch 158/2000
#
# Epoch 00158: val_loss did not improve from 0.13801
# Epoch 159/2000
#
# Epoch 00159: val_loss did not improve from 0.13801
# Epoch 160/2000
#
# Epoch 00160: val_loss did not improve from 0.13801

# %%
df_hist = pd.DataFrame(hist.history)
df_hist.head(10)
# Out:
#    val_loss  val_accuracy      loss  accuracy
# 0  0.373613      0.875000  0.501918  0.671875
# 1  0.411585      0.890625  0.481576  0.625000
# 2  0.308300      0.921875  0.549828  0.687500
# 3  0.495934      0.875000  0.513338  0.734375
# 4  0.499270      0.937500  0.510572  0.593750
# 5  0.416712      0.796875  0.613670  0.656250
# 6  0.620815      0.921875  0.399567  0.578125
# 7  0.664502      0.890625  0.583722  0.640625
# 8  0.402716      0.875000  0.468364  0.703125
# 9  0.654999      0.812500  0.456220  0.640625

# %%
fig_loss=df_hist[["val_loss","loss"]].plot(subplots=False, figsize=(15,5), fontsize=16)
fig_loss.set_ylabel("Loss value", fontsize=18)
fig_acc=df_hist[["val_accuracy","accuracy"]].plot(subplots=False, figsize=(15,5), fontsize=16)
fig_acc.set_xlabel("Epoch", fontsize=18)
fig_acc.set_ylabel("Accuracy", fontsize=18)
print(df_hist['val_loss'].min())
print(df_hist['val_accuracy'].max())
# Out:
# 0.13801336288452148
# 1.0

# %%
pred_va=model.predict([va_pairs[:,0],va_pairs[:,1]])

# %%
print("Validation accuracy: ",acc_scalar(va_y, pred_va))
# Out:
# (906,) (906,)
# 906 797
# Validation accuracy:  0.8796909492273731
